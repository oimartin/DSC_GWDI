# %%
# Import dependencies
import pandas as pd

# Save csv file name to 'file'
file = "GWDI_orders_coding_copy.csv"

# Import csv file as df
gwdi_orders = pd.read_csv(file)

# Save csv file name to 'file'
file_2 = "GWDI_all_mutants_copy.csv"

# Import csv file as df
gwdi_info = pd.read_csv(file_2)

# %%
# Rename strains ordered column of 
gwdi_orders.rename(columns={"Strains Ordered": "ID"}, inplace=True)

# Merge GWDI info and orders dfs
gwdi_info_and_orders = gwdi_orders.merge(gwdi_info.set_index('ID'), on='ID', how="inner")

# Drop unecessary columns
cleaned_gwdi = gwdi_info_and_orders.drop(["Name", "Plated", "Form Spores?", "Replated", "Shipped", 
                                          "Harvest Plate","Stored", "Tested", "Unnamed: 14", 
                                          "Chromosome", "Position",], axis=1)
cleaned_gwdi.head()
# Out:
#    Order # Order Date  Number Strains Per Order            ID Single/ Multi  \
# 0        1    4/25/18                         1   GWDI_50_D_4        single
# 1        1    4/25/18                         2  GWDI_215_G_9        single
# 2        1    4/25/18                         3  GWDI_165_A_8        single
# 3        1    4/25/18                         4  GWDI_26_B_11        single
# 4        2    4/25/18                         1  GWDI_295_B_2      multi 14
#
#       Growing? Insert  Mutants in well Insert Orientation  Disruption  \
# 0          yes     G1                1                  +  intragenic
# 1  not growing     C6                1                  -  intragenic
# 2          yes     G1                1                  -  intragenic
# 3          yes     G1                1                  -  intragenic
# 4          yes     C6               14                  +  intragenic
#
#   Disrupted Gene(s)     Gene Name
# 0      DDB_G0289731  DDB_G0289731
# 1      DDB_G0286535          gghA
# 2      DDB_G0286535          gghA
# 3      DDB_G0278295  DDB_G0278295
# 4      DDB_G0269376  DDB_G0269376

# %%
# Set index to 'Disruption' and then choose only rows with 'intragenic'
intragenic_only = cleaned_gwdi.set_index('Disruption').loc['intragenic']

# Consildated list of wells with intragenic mutant strains
intragenic_only.groupby(['ID']).mean()
# Out:
#               Order #  Number Strains Per Order  Mutants in well
# ID
# GWDI_11_A_7      20.0                       1.0              1.0
# GWDI_11_E_11      3.0                       2.0              1.0
# GWDI_12_D_2      43.0                       1.0              1.0
# GWDI_12_E_9      29.0                       1.0              1.0
# GWDI_131_E_5     51.0                       3.0              1.0
# ...               ...                       ...              ...
# GWDI_69_H_1      54.5                       2.0              1.0
# GWDI_71_B_10     26.0                       4.0              3.0
# GWDI_71_E_10     20.0                       9.0              1.0
# GWDI_71_G_11     39.0                       5.0              2.0
# GWDI_72_D_3      11.0                       3.0              1.0
#
# [282 rows x 3 columns]
